# %% [markdown]
# # Setup 1
# * libraries
# * pandas.read_csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os

import requests
from bs4 import BeautifulSoup
from requests.exceptions import ConnectionError, Timeout, RequestException

# %%
os.listdir('../data')
# Out:
# ['.DS_Store', 'cleaned_players.csv', 'df_eng.csv']

# %%
df = pd.read_csv('../data/cleaned_players.csv', index_col = 0)
df.head()
# Out:
#      id_players         player_name             birthday  height  weight  \
# 0             1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 5             2     Aaron Cresswell  1989-12-15 00:00:00  170.18     146
# 47            3         Aaron Doran  1991-05-13 00:00:00  170.18     163
# 83            4       Aaron Galindo  1982-05-08 00:00:00  182.88     198
# 106           5        Aaron Hughes  1979-11-08 00:00:00  182.88     154
#
#      overall_rating  potential preferred_foot attacking_work_rate  \
# 0              67.0       71.0          right              medium
# 5              74.0       76.0           left                high
# 47             71.0       78.0          right              medium
# 83             75.0       82.0          right              medium
# 106            78.0       81.0          right              medium
#
#     defensive_work_rate  ...  vision  penalties  marking  standing_tackle  \
# 0                medium  ...    54.0       48.0     65.0             69.0
# 5                medium  ...    66.0       59.0     76.0             75.0
# 47               medium  ...    72.0       63.0     22.0             21.0
# 83                 high  ...    54.0       60.0     80.0             78.0
# 106              medium  ...    60.0       81.0     82.0             83.0
#
#      sliding_tackle  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 0              69.0        6.0         11.0        10.0             8.0
# 5              78.0       14.0          7.0         9.0             9.0
# 47             21.0       15.0         10.0        11.0             8.0
# 83             70.0       14.0         11.0        65.0            11.0
# 106            77.0       12.0         20.0        57.0            20.0
#
#      gk_reflexes
# 0            8.0
# 5           12.0
# 47          12.0
# 83          10.0
# 106         20.0
#
# [5 rows x 43 columns]

# %% [markdown]
# # Preprocessing
# * id_players from int64 to object
# * preferred_foot encoded (left:0, right:1)
# * attacking_work_rate encoded (low:0, medium:1, high:2)
# * defensive_work_rate encoded (low:0, medium:1, high:2)

# %%
# Initial Data Types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9844 entries, 0 to 183972
# Data columns (total 43 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_players           9844 non-null   int64
#  1   player_name          9844 non-null   object
#  2   birthday             9844 non-null   object
#  3   height               9844 non-null   float64
#  4   weight               9844 non-null   int64
#  5   overall_rating       9844 non-null   float64
#  6   potential            9844 non-null   float64
#  7   preferred_foot       9844 non-null   object
#  8   attacking_work_rate  9844 non-null   object
#  9   defensive_work_rate  9844 non-null   object
#  10  crossing             9844 non-null   float64
#  11  finishing            9844 non-null   float64
#  12  heading_accuracy     9844 non-null   float64
#  13  short_passing        9844 non-null   float64
#  14  volleys              9844 non-null   float64
#  15  dribbling            9844 non-null   float64
#  16  curve                9844 non-null   float64
#  17  free_kick_accuracy   9844 non-null   float64
#  18  long_passing         9844 non-null   float64
#  19  ball_control         9844 non-null   float64
#  20  acceleration         9844 non-null   float64
#  21  sprint_speed         9844 non-null   float64
#  22  agility              9844 non-null   float64
#  23  reactions            9844 non-null   float64
#  24  balance              9844 non-null   float64
#  25  shot_power           9844 non-null   float64
#  26  jumping              9844 non-null   float64
#  27  stamina              9844 non-null   float64
#  28  strength             9844 non-null   float64
#  29  long_shots           9844 non-null   float64
#  30  aggression           9844 non-null   float64
#  31  interceptions        9844 non-null   float64
#  32  positioning          9844 non-null   float64
#  33  vision               9844 non-null   float64
#  34  penalties            9844 non-null   float64
#  35  marking              9844 non-null   float64
#  36  standing_tackle      9844 non-null   float64
#  37  sliding_tackle       9844 non-null   float64
#  38  gk_diving            9844 non-null   float64
#  39  gk_handling          9844 non-null   float64
#  40  gk_kicking           9844 non-null   float64
#  41  gk_positioning       9844 non-null   float64
#  42  gk_reflexes          9844 non-null   float64
# dtypes: float64(36), int64(2), object(5)
# memory usage: 3.3+ MB

# %%
# Let's convert ID to object so that it does not interfere with our calculations
df['id_players'] = df['id_players'].astype('object')

# Mapping dictionaries
foot_mapping = {
    'left': 0,
    'right': 1
}

workrate_mapping = {
    'low': 0,
    'medium': 1,
    'high': 2
}

# Convert the columns
df['preferred_foot'] = df['preferred_foot'].replace(foot_mapping)
df['attacking_work_rate'] = df['attacking_work_rate'].replace(workrate_mapping) 
df['defensive_work_rate'] = df['defensive_work_rate'].replace(workrate_mapping)

# Check the value counts to see if the encoding worked
print(df['preferred_foot'].value_counts())
print()
print(df['attacking_work_rate'].value_counts())
print()
print(df['defensive_work_rate'].value_counts())
# Out:
# preferred_foot
# 1    7437
# 0    2407
# Name: count, dtype: int64
#
# attacking_work_rate
# 1       6871
# 2       2388
# 0        489
# norm      55
# le        14
# stoc      14
# y         13
# Name: count, dtype: int64
#
# defensive_work_rate
# 1        7315
# 2        1519
# 0         903
# ormal      55
# ean        14
# tocky      14
# es         13
# 9           2
# 4           2
# 5           2
# 6           2
# 1           1
# 2           1
# 3           1
# Name: count, dtype: int64
# /var/folders/xs/s4fj4wdx6f7fkjpgcmjzz2lc0000gn/T/ipykernel_1797/703262197.py:17: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['preferred_foot'] = df['preferred_foot'].replace(foot_mapping)

# %% [markdown]
# * We have a lot of invalid values for defensive and attacking work rate which are small enough for us to remove
# * We will remove this from our dataset so that we can continue the analysis

# %%
valid_values = [0, 1, 2]

# Filtering only the valid values in both columns
df = df[df['attacking_work_rate'].isin(valid_values)]
df = df[df['defensive_work_rate'].isin(valid_values)]

# Converting from object to integer
df['attacking_work_rate'] = df['attacking_work_rate'].astype('int64')
df['defensive_work_rate'] = df['defensive_work_rate'].astype('int64')

# %%
# New Data Types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9737 entries, 0 to 183972
# Data columns (total 43 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id_players           9737 non-null   object
#  1   player_name          9737 non-null   object
#  2   birthday             9737 non-null   object
#  3   height               9737 non-null   float64
#  4   weight               9737 non-null   int64
#  5   overall_rating       9737 non-null   float64
#  6   potential            9737 non-null   float64
#  7   preferred_foot       9737 non-null   int64
#  8   attacking_work_rate  9737 non-null   int64
#  9   defensive_work_rate  9737 non-null   int64
#  10  crossing             9737 non-null   float64
#  11  finishing            9737 non-null   float64
#  12  heading_accuracy     9737 non-null   float64
#  13  short_passing        9737 non-null   float64
#  14  volleys              9737 non-null   float64
#  15  dribbling            9737 non-null   float64
#  16  curve                9737 non-null   float64
#  17  free_kick_accuracy   9737 non-null   float64
#  18  long_passing         9737 non-null   float64
#  19  ball_control         9737 non-null   float64
#  20  acceleration         9737 non-null   float64
#  21  sprint_speed         9737 non-null   float64
#  22  agility              9737 non-null   float64
#  23  reactions            9737 non-null   float64
#  24  balance              9737 non-null   float64
#  25  shot_power           9737 non-null   float64
#  26  jumping              9737 non-null   float64
#  27  stamina              9737 non-null   float64
#  28  strength             9737 non-null   float64
#  29  long_shots           9737 non-null   float64
#  30  aggression           9737 non-null   float64
#  31  interceptions        9737 non-null   float64
#  32  positioning          9737 non-null   float64
#  33  vision               9737 non-null   float64
#  34  penalties            9737 non-null   float64
#  35  marking              9737 non-null   float64
#  36  standing_tackle      9737 non-null   float64
#  37  sliding_tackle       9737 non-null   float64
#  38  gk_diving            9737 non-null   float64
#  39  gk_handling          9737 non-null   float64
#  40  gk_kicking           9737 non-null   float64
#  41  gk_positioning       9737 non-null   float64
#  42  gk_reflexes          9737 non-null   float64
# dtypes: float64(36), int64(4), object(3)
# memory usage: 3.3+ MB

# %% [markdown]
# # Feature Engineering
# 1. birth_year instead of birthday
# 2. age
# 3. position (webscraping transfermarkt.com)
# 4. country (webscraping transfermarkt.com)

# %%
# Convert birthday to datetime if not already
df['birthday'] = pd.to_datetime(df['birthday'])

# Extract year
df['birth_year'] = df['birthday'].dt.year

# Calculate age (as of 2024)
current_year = 2024
df['age'] = current_year - df['birth_year']

# Drop original birthday column if no longer needed
df = df.drop('birthday', axis=1)

# %%
# Wescraping Countries and Positions of players
countries = []
positions = []
n = len(df)

for i in range(n):
    player_name = df.iloc[i]['player_name'].lower()
    search_url = f"https://www.transfermarkt.com/schnellsuche/ergebnis/schnellsuche?query={'+'.join(player_name.split())}"
    
    try:
        response = requests.get(search_url, headers={"User-Agent": "Mozilla/5.0"}, timeout=10)
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract position
        position_td = soup.find('td', class_='zentriert')
        position = position_td.get_text(strip=True) if position_td else "NA"

        # Extract country
        country_img_tag = soup.find('img', class_='flaggenrahmen')
        country_name = country_img_tag.get('title') if country_img_tag else "NA"

        # Append the extracted information to the list
        countries.append(country_name)
        positions.append(position)
        print(f"Player {i+1}/{n} Found! Position: {position}, Country: {country_name}")
    
    except (ConnectionError, Timeout) as e:
        countries.append(np.nan)
        positions.append(np.nan)
        print(f"Player {i+1}/{n} Failed due to connection issue: {e}")
    
    except Exception as e:
        countries.append(np.nan)
        positions.append(np.nan)
        print(f"Player {i+1}/{n} Failed due to unexpected error: {e}")
# Out:
# Player 1/9737 Found! Position: CB, Country: Gabon
# Player 2/9737 Found! Position: LB, Country: England
# Player 3/9737 Found! Position: RM, Country: Ireland
# Player 4/9737 Found! Position: CB, Country: Mexico
# Player 5/9737 Found! Position: CB, Country: Northern Ireland
# Player 6/9737 Found! Position: AM, Country: Germany
# Player 7/9737 Found! Position: CM, Country: England
# Player 8/9737 Found! Position: RW, Country: England
# Player 9/9737 Found! Position: GK, Country: Australia
# Player 10/9737 Found! Position: LB, Country: Netherlands
# Player 11/9737 Found! Position: CB, Country: South Africa
# Player 12/9737 Found! Position: CM, Country: Australia
# Player 13/9737 Found! Position: RB, Country: Scotland
# Player 14/9737 Found! Position: RW, Country: Spain
# Player 15/9737 Found! Position: CM, Country: Wales
# Player 16/9737 Found! Position: CM, Country: Scotland
# Player 17/9737 Found! Position: LB, Country: Antigua and Barbuda
# Player 18/9737 Found! Position: CF, Country: England
# Player 19/9737 Found! Position: AM, Country: Morocco
# Player 20/9737 Found! Position: AM, Country: Morocco
# Player 21/9737 Found! Position: CB, Country: Morocco
# Player 22/9737 Found! Position: CF, Country: Algeria
# Player 23/9737 Found! Position: LW, Country: France
# Player 24/9737 Found! Position: CM, Country: Netherlands
# Player 25/9737 Found! Position: RB, Country: Morocco
# Player 26/9737 Found! Position: NA, Country: NA
# Player 27/9737 Found! Position: CB, Country: Senegal
# Player 28/9737 Found! Position: AM, Country: Burkina Faso
# Player 29/9737 Found! Position: CM, Country: Burkina Faso
# Player 30/9737 Found! Position: , Country: NA
# Player 31/9737 Found! Position: LW, Country: Guinea
# Player 32/9737 Found! Position: RB, Country: France
# Player 33/9737 Found! Position: CB, Country: Senegal
# Player 34/9737 Found! Position: CB, Country: Cote d'Ivoire
# Player 35/9737 Found! Position: CB, Country: Mali
# Player 36/9737 Found! Position: GK, Country: Senegal
# Player 37/9737 Found! Position: CM, Country: Mali
# Player 38/9737 Found! Position: CB, Country: Senegal
# Player 39/9737 Failed due to connection issue: HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)
# Player 40/9737 Found! Position: CB, Country: Cote d'Ivoire
# Player 41/9737 Found! Position: DM, Country: Guinea
# Player 42/9737 Found! Position: DM, Country: Mali
# Player 43/9737 Found! Position: DM, Country: The Gambia
# Player 44/9737 Found! Position: , Country: NA
# Player 45/9737 Found! Position: SS, Country: Ghana
# Player 46/9737 Found! Position: CM, Country: Ghana
# Player 47/9737 Found! Position: LB, Country: Ghana
# Player 48/9737 Found! Position: , Country: NA
# Player 49/9737 Found! Position: , Country: NA
# Player 50/9737 Found! Position: AM, Country: Bahrain
# Player 51/9737 Found! Position: NA, Country: NA
# Player 52/9737 Found! Position: DM, Country: Nigeria
# Player 53/9737 Found! Position: DM, Country: Colombia
# Player 54/9737 Found! Position: CM, Country: Spain
# Player 55/9737 Found! Position: CF, Country: Uruguay
# Player 56/9737 Found! Position: CF, Country: Guinea-Bissau
# Player 57/9737 Found! Position: RW, Country: Algeria
# Player 58/9737 Found! Position: LB, Country: DR Congo
# Player 59/9737 Found! Position: , Country: NA
# Player 60/9737 Found! Position: CF, Country: Nigeria
# Player 61/9737 Found! Position: CM, Country: France
# Player 62/9737 Found! Position: CF, Country: Mauritania
# Player 63/9737 Found! Position: CM, Country: Spain
# Player 64/9737 Found! Position: NA, Country: NA
# Player 65/9737 Found! Position: DM, Country: Ghana
# Player 66/9737 Found! Position: LB, Country: Spain
# Player 67/9737 Found! Position: CB, Country: Spain
# Player 68/9737 Found! Position: GK, Country: Italy
# Player 131/9737 Found! Position: DM, Country: Morocco
# Player 132/9737 Found! Position: CB, Country: France
# Player 133/9737 Found! Position: LM, Country: Morocco
# Player 134/9737 Found! Position: CB, Country: Brazil
# Player 135/9737 Found! Position: CF, Country: North Macedonia
# Player 136/9737 Found! Position: DM, Country: Algeria
# Player 137/9737 Found! Position: CF, Country: Bosnia-Herzegovina
# Player 138/9737 Found! Position: SS, Country: Switzerland
# Player 139/9737 Found! Position: CM, Country: Netherlands
# Player 140/9737 Found! Position: RW, Country: Bosnia-Herzegovina
# Player 141/9737 Found! Position: RW, Country: Belgium
# Player 142/9737 Found! Position: CB, Country: Bosnia-Herzegovina
# Player 143/9737 Found! Position: LW, Country: Morocco
# Player 144/9737 Found! Position: LB, Country: Brazil
# Player 145/9737 Found! Position: RB, Country: Poland
# Player 146/9737 Found! Position: AM, Country: Poland
# Player 147/9737 Found! Position: CF, Country: Spain
# Player 148/9737 Found! Position: LW, Country: Romania
# Player 149/9737 Found! Position: DM, Country: Argentina
# Player 150/9737 Found! Position: RW, Country: Spain
# Player 151/9737 Found! Position: CM, Country: Spain
# Player 152/9737 Found! Position: RB, Country: Uruguay
# Player 153/9737 Found! Position: RB, Country: Poland
# Player 154/9737 Found! Position: CF, Country: Spain
# Player 155/9737 Found! Position: CB, Country: Jamaica
# Player 156/9737 Found! Position: LB, Country: Spain
# Player 157/9737 Found! Position: DM, Country: Poland
# Player 158/9737 Found! Position: LW, Country: Romania
# Player 159/9737 Found! Position: LW, Country: Switzerland
# Player 160/9737 Found! Position: DM, Country: Poland
# Player 161/9737 Found! Position: CF, Country: Colombia
# Player 162/9737 Found! Position: LW, Country: Argentina
# Player 163/9737 Found! Position: SS, Country: Argentina
# Player 164/9737 Found! Position: LW, Country: Spain
# Player 165/9737 Found! Position: LW, Country: Romania
# Player 166/9737 Found! Position: RM, Country: Switzerland
# Player 167/9737 Found! Position: LB, Country: Brazil
# Player 168/9737 Found! Position: CB, Country: Switzerland
# Player 169/9737 Found! Position: GK, Country: Brazil
# Player 170/9737 Found! Position: RW, Country: Brazil
# Player 171/9737 Found! Position: RB, Country: Brazil
# Player 172/9737 Found! Position: RB, Country: Brazil
# Player 173/9737 Found! Position: CB, Country: Italy
# Player 174/9737 Found! Position: CF, Country: France
# Player 175/9737 Found! Position: CM, Country: France
# Player 176/9737 Found! Position: RB, Country: Switzerland
# Player 177/9737 Found! Position: AM, Country: Morocco
# Player 178/9737 Found! Position: CM, Country: Portugal
# Player 179/9737 Found! Position: AM, Country: France
# Player 180/9737 Found! Position: CM, Country: Madagascar
# Player 181/9737 Found! Position: AM, Country: Brazil
# Player 182/9737 Found! Position: AM, Country: Portugal
# Player 183/9737 Found! Position: CM, Country: Ghana
# Player 184/9737 Found! Position: RW, Country: Spain
# Player 185/9737 Found! Position: RW, Country: North Macedonia
# Player 186/9737 Found! Position: CF, Country: Albania
# Player 187/9737 Found! Position: CF, Country: Argentina
# Player 188/9737 Found! Position: RB, Country: Morocco
# Player 189/9737 Found! Position: DM, Country: Ghana
# Player 311/9737 Found! Position: CB, Country: Serbia
# Player 312/9737 Found! Position: CF, Country: Serbia
# Player 313/9737 Found! Position: CF, Country: Serbia
# Player 314/9737 Found! Position: CM, Country: Germany
# Player 315/9737 Found! Position: RB, Country: North Macedonia
# Player 316/9737 Found! Position: LW, Country: Bulgaria
# Player 317/9737 Found! Position: LW, Country: North Macedonia
# Player 318/9737 Found! Position: LW, Country: Poland
# Player 319/9737 Found! Position: AM, Country: Poland
# Player 320/9737 Found! Position: , Country: NA
# Player 321/9737 Found! Position: AM, Country: Belarus
# Player 322/9737 Found! Position: DM, Country: Latvia
# Player 323/9737 Found! Position: CF, Country: Finland
# Player 324/9737 Found! Position: AM, Country: Croatia
# Player 325/9737 Found! Position: CF, Country: Serbia
# Player 326/9737 Found! Position: LW, Country: Serbia
# Player 327/9737 Found! Position: NA, Country: NA
# Player 328/9737 Found! Position: LB, Country: Italy
# Player 329/9737 Found! Position: CB, Country: Italy
# Player 330/9737 Found! Position: DM, Country: Italy
# Player 331/9737 Found! Position: LW, Country: Italy
# Player 332/9737 Found! Position: CF, Country: Belgium
# Player 333/9737 Found! Position: LB, Country: Italy
# Player 334/9737 Found! Position: GK, Country: Netherlands
# Player 335/9737 Found! Position: SS, Country: Italy
# Player 336/9737 Found! Position: AM, Country: Italy
# Player 337/9737 Found! Position: RB, Country: Italy
# Player 338/9737 Found! Position: DM, Country: Italy
# Player 339/9737 Found! Position: CB, Country: Italy
# Player 340/9737 Found! Position: DM, Country: Italy
# Player 341/9737 Found! Position: GK, Country: Italy
# Player 342/9737 Found! Position: LB, Country: Switzerland
# Player 343/9737 Found! Position: CB, Country: Italy
# Player 344/9737 Found! Position: CB, Country: Italy
# Player 345/9737 Found! Position: CB, Country: Italy
# Player 346/9737 Found! Position: CF, Country: Italy
# Player 347/9737 Found! Position: CB, Country: Italy
# Player 348/9737 Found! Position: LB, Country: Italy
# Player 349/9737 Found! Position: SS, Country: Italy
# Player 350/9737 Found! Position: RB, Country: Italy
# Player 351/9737 Found! Position: RW, Country: Italy
# Player 352/9737 Found! Position: AM, Country: Austria
# Player 353/9737 Found! Position: SS, Country: Italy
# Player 354/9737 Found! Position: RW, Country: Italy
# Player 355/9737 Found! Position: GK, Country: Italy
# Player 356/9737 Found! Position: AM, Country: Cape Verde
# Player 357/9737 Found! Position: CB, Country: Italy
# Player 358/9737 Found! Position: GK, Country: Italy
# Player 359/9737 Found! Position: RW, Country: Italy
# Player 360/9737 Found! Position: RB, Country: England
# Player 361/9737 Found! Position: CB, Country: England
# Player 362/9737 Found! Position: CB, Country: Northern Ireland
# Player 363/9737 Found! Position: GK, Country: Italy
# Player 364/9737 Found! Position: LB, Country: Scotland
# Player 365/9737 Found! Position: CM, Country: Spain
# Player 366/9737 Found! Position: CB, Country: Italy
# Player 367/9737 Found! Position: CF, Country: Brazil
# Player 368/9737 Found! Position: LM, Country: Scotland
# Player 369/9737 Found! Position: LM, Country: England
# Player 370/9737 Found! Position: LW, Country: Nigeria
# Player 371/9737 Found! Position: NA, Country: NA
# Player 615/9737 Found! Position: CB, Country: Italy
# Player 616/9737 Found! Position: GK, Country: Italy
# Player 617/9737 Found! Position: RB, Country: Italy
# Player 618/9737 Found! Position: AM, Country: Italy
# Player 619/9737 Found! Position: CB, Country: Italy
# Player 620/9737 Found! Position: LM, Country: Italy
# Player 621/9737 Found! Position: CB, Country: Italy
# Player 622/9737 Found! Position: CF, Country: Belgium
# Player 623/9737 Found! Position: GK, Country: Italy
# Player 624/9737 Found! Position: CM, Country: Italy
# Player 625/9737 Found! Position: CB, Country: Italy
# Player 626/9737 Found! Position: DM, Country: Italy
# Player 627/9737 Found! Position: CB, Country: Italy
# Player 628/9737 Found! Position: CB, Country: Italy
# Player 629/9737 Found! Position: AM, Country: Italy
# Player 630/9737 Found! Position: CB, Country: Italy
# Player 631/9737 Found! Position: LM, Country: DR Congo
# Player 632/9737 Found! Position: CM, Country: Italy
# Player 633/9737 Found! Position: DM, Country: Italy
# Player 634/9737 Found! Position: DM, Country: Italy
# Player 635/9737 Found! Position: RM, Country: Italy
# Player 636/9737 Found! Position: CM, Country: Italy
# Player 637/9737 Found! Position: CB, Country: Italy
# Player 638/9737 Found! Position: CB, Country: Italy
# Player 639/9737 Found! Position: RB, Country: Italy
# Player 640/9737 Found! Position: LB, Country: Italy
# Player 641/9737 Found! Position: AM, Country: Italy
# Player 642/9737 Found! Position: GK, Country: Italy
# Player 643/9737 Found! Position: CM, Country: Italy
# Player 644/9737 Found! Position: RB, Country: Germany
# Player 645/9737 Found! Position: CB, Country: Denmark
# Player 646/9737 Found! Position: CB, Country: Denmark
# Player 647/9737 Found! Position: NA, Country: NA
# Player 648/9737 Found! Position: CB, Country: Sweden
# Player 649/9737 Found! Position: RB, Country: Germany
# Player 650/9737 Found! Position: GK, Country: Switzerland
# Player 651/9737 Found! Position: LB, Country: Austria
# Player 652/9737 Found! Position: GK, Country: Sweden
# Player 653/9737 Found! Position: AM, Country: Austria
# Player 654/9737 Found! Position: CM, Country: Sweden
# Player 655/9737 Found! Position: CM, Country: Germany
# Player 656/9737 Found! Position: RB, Country: Sweden
# Player 657/9737 Found! Position: AM, Country: Austria
# Player 658/9737 Found! Position: CM, Country: Germany
# Player 659/9737 Found! Position: GK, Country: Germany
# Player 660/9737 Found! Position: DM, Country: Germany
# Player 661/9737 Found! Position: DM, Country: Greece
# Player 662/9737 Found! Position: AM, Country: Austria
# Player 663/9737 Found! Position: LB, Country: Switzerland
# Player 664/9737 Found! Position: CB, Country: Germany
# Player 665/9737 Found! Position: CF, Country: Croatia
# Player 666/9737 Found! Position: RW, Country: Slovakia
# Player 667/9737 Found! Position: GK, Country: Spain
# Player 668/9737 Found! Position: CM, Country: Mexico
# Player 669/9737 Found! Position: CM, Country: Spain
# Player 670/9737 Found! Position: CB, Country: Uruguay
# Player 671/9737 Found! Position: DM, Country: Argentina
# Player 672/9737 Found! Position: GK, Country: Switzerland
# Player 673/9737 Found! Position: GK, Country: Spain
# Player 674/9737 Found! Position: CB, Country: Venezuela
# Player 675/9737 Found! Position: CB, Country: Spain
# Player 676/9737 Found! Position: , Country: NA
# Player 677/9737 Found! Position: CF, Country: Scotland
# Player 678/9737 Found! Position: CB, Country: Scotland
# Player 679/9737 Found! Position: CM, Country: Wales
# Player 680/9737 Found! Position: CB, Country: England
# Player 681/9737 Found! Position: NA, Country: NA
# Player 682/9737 Found! Position: NA, Country: NA
# Player 683/9737 Found! Position: CF, Country: England
# Player 684/9737 Found! Position: NA, Country: NA
# Player 685/9737 Found! Position: CF, Country: Northern Ireland
# Player 686/9737 Found! Position: Midfield, Country: England
# Player 687/9737 Found! Position: CB, Country: Ireland
# Player 688/9737 Found! Position: LM, Country: Ireland
# Player 689/9737 Found! Position: LB, Country: Scotland
# Player 690/9737 Found! Position: AM, Country: Scotland
# Player 691/9737 Found! Position: CB, Country: Zambia
# Player 692/9737 Found! Position: CM, Country: England
# Player 693/9737 Found! Position: LB, Country: England
# Player 694/9737 Found! Position: CF, Country: United States
# Player 695/9737 Found! Position: LW, Country: Russia
# Player 696/9737 Found! Position: Defender, Country: Belarus
# Player 697/9737 Found! Position: AM, Country: Brazil
# Player 698/9737 Found! Position: CF, Country: Montenegro
# Player 699/9737 Found! Position: CF, Country: Serbia
# Player 700/9737 Found! Position: GK, Country: Latvia
# Player 701/9737 Found! Position: RW, Country: England
# Player 702/9737 Found! Position: GK, Country: Poland
# Player 703/9737 Found! Position: RW, Country: Netherlands
# Player 704/9737 Found! Position: CF, Country: England
# Player 705/9737 Found! Position: CF, Country: Algeria
# Player 706/9737 Found! Position: DM, Country: Wales
# Player 707/9737 Found! Position: CB, Country: Scotland
# Player 708/9737 Found! Position: RB, Country: England
# Player 709/9737 Found! Position: LW, Country: Belgium
# Player 710/9737 Found! Position: CM, Country: Wales
# Player 711/9737 Found! Position: CF, Country: Northern Ireland
# Player 712/9737 Found! Position: RB, Country: Honduras
# Player 713/9737 Found! Position: CB, Country: Scotland
# Player 714/9737 Found! Position: RB, Country: England
# Player 715/9737 Found! Position: RB, Country: South Africa
# Player 716/9737 Found! Position: RB, Country: Greece
# Player 717/9737 Found! Position: NA, Country: NA
# Player 718/9737 Found! Position: RW, Country: Argentina
# Player 719/9737 Found! Position: RW, Country: Argentina
# Player 720/9737 Found! Position: CF, Country: Spain
# Player 721/9737 Found! Position: LW, Country: Spain
# Player 722/9737 Found! Position: Defender, Country: Argentina
# Player 723/9737 Found! Position: CM, Country: Spain
# Player 724/9737 Found! Position: RB, Country: Spain
# Player 725/9737 Found! Position: CF, Country: Spain
# Player 726/9737 Found! Position: CB, Country: Spain
# Player 727/9737 Found! Position: GK, Country: Italy
# Player 728/9737 Found! Position: CB, Country: Italy
# Player 729/9737 Found! Position: DM, Country: Italy
# Player 730/9737 Found! Position: GK, Country: Brazil
# Player 731/9737 Found! Position: CF, Country: Greece
# Player 732/9737 Found! Position: CB, Country: Portugal
# Player 733/9737 Found! Position: CF, Country: Tunisia
# Player 734/9737 Found! Position: CB, Country: Brazil
# Player 735/9737 Found! Position: AM, Country: Tunisia
# Player 736/9737 Found! Position: DM, Country: Morocco
# Player 9704/9737 Found! Position: RB, Country: Czech Republic
# Player 9705/9737 Found! Position: CM, Country: Serbia
# Player 9706/9737 Found! Position: CB, Country: Portugal
# Player 9707/9737 Found! Position: CM, Country: Brazil
# Player 9708/9737 Found! Position: CF, Country: Cape Verde
# Player 9709/9737 Found! Position: LM, Country: Brazil
# Player 9710/9737 Found! Position: CM, Country: Greece
# Player 9711/9737 Found! Position: GK, Country: Serbia
# Player 9712/9737 Found! Position: CM, Country: Guinea-Bissau
# Player 9713/9737 Found! Position: DM, Country: China
# Player 9714/9737 Found! Position: AM, Country: Germany
# Player 9715/9737 Found! Position: LB, Country: Cote d'Ivoire
# Player 9716/9737 Found! Position: CB, Country: Scotland
# Player 9717/9737 Found! Position: RW, Country: Belgium
# Player 9718/9737 Found! Position: AM, Country: France
# Player 9719/9737 Found! Position: CF, Country: Guinea-Bissau
# Player 9720/9737 Found! Position: RW, Country: Algeria
# Player 9721/9737 Found! Position: RW, Country: Egypt
# Player 9722/9737 Found! Position: CF, Country: Sweden
# Player 9723/9737 Found! Position: CF, Country: Slovenia
# Player 9724/9737 Found! Position: CF, Country: Bosnia-Herzegovina
# Player 9725/9737 Found! Position: CM, Country: Austria
# Player 9726/9737 Found! Position: LM, Country: DR Congo
# Player 9727/9737 Found! Position: AM, Country: Hungary
# Player 9728/9737 Found! Position: AM, Country: Hungary
# Player 9729/9737 Found! Position: RB, Country: Hungary
# Player 9730/9737 Found! Position: CF, Country: Switzerland
# Player 9731/9737 Found! Position: CB, Country: Serbia
# Player 9732/9737 Found! Position: RW, Country: Serbia
# Player 9733/9737 Found! Position: NA, Country: NA
# Player 9734/9737 Found! Position: CB, Country: Morocco
# Player 9735/9737 Found! Position: CB, Country: France
# Player 9736/9737 Found! Position: LB, Country: Hungary
# Player 9737/9737 Found! Position: AM, Country: Bosnia-Herzegovina

# %%
# Saving the new features as columns in the df
df['position'] = positions
df['country'] = countries

# %%
# There are some players who were not found on the website
df[['position', 'country']].isnull().sum()
# Out:
# position    544
# country     545
# dtype: int64

# %%
# let's remove the NAs from this
# we already removed the previous NAs, so we can simply drop all NAs
df = df.dropna()

# %%
# Overwriting the new dataframe
df.to_csv('../data/cleaned_players_2.csv', index=False)

# %% [markdown]
# # Setup 2

# %%
# Base
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Statsmodels
import statsmodels.api as sm

# Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline

# Algorithms
from sklearn.cluster import KMeans
from sklearn.linear_model import LassoCV

# Metrics
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('../data/cleaned_players_2.csv', index_col = 0)
df.head()
# Out:
#                    player_name  height  weight  overall_rating  potential  \
# id_players
# 1           Aaron Appindangoye  182.88     187            67.0       71.0
# 2              Aaron Cresswell  170.18     146            74.0       76.0
# 3                  Aaron Doran  170.18     163            71.0       78.0
# 4                Aaron Galindo  182.88     198            75.0       82.0
# 5                 Aaron Hughes  182.88     154            78.0       81.0
#
#             preferred_foot  attacking_work_rate  defensive_work_rate  \
# id_players
# 1                        1                    1                    1
# 2                        0                    2                    1
# 3                        1                    1                    1
# 4                        1                    1                    2
# 5                        1                    1                    1
#
#             crossing  finishing  ...  sliding_tackle  gk_diving  gk_handling  \
# id_players                       ...
# 1               49.0       44.0  ...            69.0        6.0         11.0
# 2               80.0       53.0  ...            78.0       14.0          7.0
# 3               73.0       52.0  ...            21.0       15.0         10.0
# 4               60.0       44.0  ...            70.0       14.0         11.0
# 5               45.0       57.0  ...            77.0       12.0         20.0
#
#             gk_kicking  gk_positioning  gk_reflexes  birth_year  age  \
# id_players
# 1                 10.0             8.0          8.0        1992   32
# 2                  9.0             9.0         12.0        1989   35
# 3                 11.0             8.0         12.0        1991   33
# 4                 65.0            11.0         10.0        1982   42
# 5                 57.0            20.0         20.0        1979   45
#
#             position           country
# id_players
# 1                 CB             Gabon
# 2                 LB           England
# 3                 RM           Ireland
# 4                 CB            Mexico
# 5                 CB  Northern Ireland
#
# [5 rows x 45 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9192 entries, 1 to 11075
# Data columns (total 45 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player_name          9192 non-null   object
#  1   height               9192 non-null   float64
#  2   weight               9192 non-null   int64
#  3   overall_rating       9192 non-null   float64
#  4   potential            9192 non-null   float64
#  5   preferred_foot       9192 non-null   int64
#  6   attacking_work_rate  9192 non-null   int64
#  7   defensive_work_rate  9192 non-null   int64
#  8   crossing             9192 non-null   float64
#  9   finishing            9192 non-null   float64
#  10  heading_accuracy     9192 non-null   float64
#  11  short_passing        9192 non-null   float64
#  12  volleys              9192 non-null   float64
#  13  dribbling            9192 non-null   float64
#  14  curve                9192 non-null   float64
#  15  free_kick_accuracy   9192 non-null   float64
#  16  long_passing         9192 non-null   float64
#  17  ball_control         9192 non-null   float64
#  18  acceleration         9192 non-null   float64
#  19  sprint_speed         9192 non-null   float64
#  20  agility              9192 non-null   float64
#  21  reactions            9192 non-null   float64
#  22  balance              9192 non-null   float64
#  23  shot_power           9192 non-null   float64
#  24  jumping              9192 non-null   float64
#  25  stamina              9192 non-null   float64
#  26  strength             9192 non-null   float64
#  27  long_shots           9192 non-null   float64
#  28  aggression           9192 non-null   float64
#  29  interceptions        9192 non-null   float64
#  30  positioning          9192 non-null   float64
#  31  vision               9192 non-null   float64
#  32  penalties            9192 non-null   float64
#  33  marking              9192 non-null   float64
#  34  standing_tackle      9192 non-null   float64
#  35  sliding_tackle       9192 non-null   float64
#  36  gk_diving            9192 non-null   float64
#  37  gk_handling          9192 non-null   float64
#  38  gk_kicking           9192 non-null   float64
#  39  gk_positioning       9192 non-null   float64
#  40  gk_reflexes          9192 non-null   float64
#  41  birth_year           9192 non-null   int64
#  42  age                  9192 non-null   int64
#  43  position             9192 non-null   object
#  44  country              9192 non-null   object
# dtypes: float64(36), int64(6), object(3)
# memory usage: 3.2+ MB

# %% [markdown]
# # Question 1
# * Question: Are there distinct player types (e.g., playmakers, defenders) based on specific attribute clusters? How do these types affect team dynamics?
# * Rationale: A client in team management could use this to balance and optimize team composition by understanding distinct player roles and strengths.

# %%
# Define attribute groups
attacking_attrs = ['finishing', 'shot_power', 'volleys', 'dribbling', 'ball_control', 'acceleration', 'sprint_speed']
midfield_attrs = ['short_passing', 'ball_control', 'vision', 'stamina', 'interceptions']
defensive_attrs = ['marking', 'standing_tackle', 'sliding_tackle', 'interceptions', 'strength']
goalkeeper_attrs = ['gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']

# %%
# Combine all attributes for clustering
all_attrs = list(set(attacking_attrs + midfield_attrs + defensive_attrs + goalkeeper_attrs))

# Prepare data for clustering
X = df[all_attrs]

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Perform K-means clustering (k=9 for 3 positions × 3 styles)
kmeans = KMeans(n_clusters=10, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_scaled)

# Calculate mean values for each cluster
cluster_means = df.groupby('Cluster')[all_attrs].mean()

# %%
# Function to identify cluster characteristics
def identify_cluster_type(cluster_means_row):
    attack_score = cluster_means_row[attacking_attrs].mean()
    midfield_score = cluster_means_row[midfield_attrs].mean()
    defense_score = cluster_means_row[defensive_attrs].mean()
    goalkeeper_score = cluster_means_row[goalkeeper_attrs].mean()
    
    
    if goalkeeper_score > 50:  
        return "Goalkeeper"
    
    # For other positions
    scores = [attack_score, midfield_score, defense_score]
    max_score = max(scores)
    
    if max_score == attack_score:
        position = "Forward"
    elif max_score == midfield_score:
        position = "Midfielder"
    else:
        position = "Defender"
        
    if attack_score > defense_score:
        style = "Attacking"
    elif defense_score > attack_score:
        style = "Defensive"
    else:
        style = "Balanced"
        
    return f"{position} ({style})"

# %%
cluster_means = df.groupby('Cluster')[all_attrs].mean()
cluster_types = {}
for cluster in range(10):
    cluster_types[cluster] = identify_cluster_type(cluster_means.loc[cluster])

# %%
# Add position and style labels to dataframe
df['Player_Type'] = df['Cluster'].map(cluster_types)

# Visualize clusters using PCA
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

plt.figure(figsize=(12, 8))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=df['Cluster'], cmap='tab10')
plt.title('Player Clusters')
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
# Add legend
legend_elements = [plt.Line2D([0], [0], marker='o', color='w', 
                            markerfacecolor=scatter.cmap(scatter.norm(i)),
                            label=cluster_types[i], markersize=10)
                  for i in range(9)]
plt.legend(handles=legend_elements, title='Player Types')
plt.tight_layout()
plt.show()

# %%
# Print top 10 players from each cluster sorted by overall rating
for cluster in range(9):
    print(f"\n\nCluster {cluster} - {cluster_types[cluster]}:")
    print("-" * 50)
    
    # Get top 10 players from this cluster
    cluster_players = df[df['Cluster'] == cluster].nlargest(10, 'overall_rating')
    
    # Display player names and key attributes based on position type
    if cluster_types[cluster].startswith('Forward'):
        relevant_attrs = attacking_attrs
    elif cluster_types[cluster].startswith('Midfielder'):
        relevant_attrs = midfield_attrs
    else:
        relevant_attrs = defensive_attrs
    
    # Print players and their key attributes
    display_cols = ['player_name', 'overall_rating'] + relevant_attrs
    print(cluster_players[display_cols].to_string())
# Out:
# Cluster 0 - Midfielder (Attacking):
# --------------------------------------------------
#                 player_name  overall_rating  short_passing  ball_control  vision  stamina  interceptions
# id_players
# 4972             Joan Verdu            80.0           84.0          80.0    87.0     56.0           49.0
# 2426          David Trezeguet            90.0       93.0        90.0     89.0       87.0          88.0          84.0          91.0
# 3482          Francesco Totti            90.0       82.0        89.0     88.0       91.0          92.0          86.0          89.0
# 3514            Franck Ribery            90.0       79.0        76.0     81.0       93.0          92.0          92.0          90.0
# 5592                     Kaka            90.0       92.0        87.0     87.0       94.0          94.0          90.0          91.0
#
#
# Cluster 7 - Defender (Defensive):
# --------------------------------------------------
#                   player_name  overall_rating  marking  standing_tackle  sliding_tackle  interceptions  strength
# id_players
# 5120               John Terry            91.0     93.0             95.0            87.0           86.0      93.0
# 4609          Jamie Carragher            88.0     93.0             92.0            87.0           88.0      85.0
# 3866        Giorgio Chiellini            87.0     91.0             91.0            91.0           87.0      89.0
# 679           Andrea Barzagli            85.0     90.0             90.0            88.0           92.0      85.0
# 7602                  Miranda            85.0     89.0             90.0            89.0           88.0      80.0
# 8542                     Pepe            85.0     85.0             88.0            93.0           85.0      84.0
# 6005        Laurent Koscielny            84.0     83.0             87.0            85.0           85.0      73.0
# 6037              Ledley King            84.0     82.0             85.0            76.0           84.0      92.0
# 7960         Nicolas Otamendi            84.0     83.0             86.0            86.0           86.0      82.0
# 1064          Aymeric Laporte            83.0     86.0             88.0            85.0           85.0      83.0
#
#
# Cluster 8 - Midfielder (Defensive):
# --------------------------------------------------
#                  player_name  overall_rating  short_passing  ball_control  vision  stamina  interceptions
# id_players
# 388         Alessandro Nesta            91.0           54.0          69.0    76.0     88.0           92.0
# 3544           Frank Lampard            90.0           92.0          90.0    89.0     92.0           83.0
# 1530            Carles Puyol            89.0           73.0          67.0    73.0     86.0           89.0
# 1952                    Cris            89.0           78.0          84.0    70.0     85.0           78.0
# 6316                   Lucio            89.0           64.0          82.0    78.0     82.0           89.0
# 10028         Steven Gerrard            89.0           91.0          88.0    86.0     95.0           86.0
# 706             Andrea Pirlo            88.0           94.0          92.0    94.0     89.0           94.0
# 7353          Michael Essien            88.0           92.0          85.0    85.0     96.0           91.0
# 8996           Rio Ferdinand            88.0           71.0          78.0    69.0     80.0           83.0
# 442                     Alex            87.0           58.0          82.0    66.0     89.0           70.0

# %%
def find_random_player_by_style(position, style=None, df=df, cluster_types=cluster_types):

    # Get matching clusters based on position and style
    matching_clusters = []
    for cluster, type_name in cluster_types.items():
        if position == 'Goalkeeper' and type_name == 'Goalkeeper':
            matching_clusters.append(cluster)
        elif position in type_name and (style is None or style in type_name):
            matching_clusters.append(cluster)
    
    if not matching_clusters:
        return f"No players found for {position} {style if style else ''}"
    
    # Get players from matching clusters
    matching_players = df[df['Cluster'].isin(matching_clusters)]
    
    # Select random player
    random_player = matching_players.sample(n=1)
    
    # Get relevant attributes
    if position == 'Goalkeeper':
        relevant_attrs = goalkeeper_attrs
    elif position == 'Forward':
        relevant_attrs = attacking_attrs
    elif position == 'Midfielder':
        relevant_attrs = midfield_attrs
    else:
        relevant_attrs = defensive_attrs
    
    display_cols = ['player_name', 'overall_rating'] + relevant_attrs
    return random_player[display_cols]

# %%
print("Random Attacking Forward:")
print(find_random_player_by_style('Forward', 'Attacking'))
# Out:
# Random Attacking Forward:
#              player_name  overall_rating  finishing  shot_power  volleys  \
# id_players
# 5717        Kenny Miller            78.0       84.0        79.0     74.0
#
#             dribbling  ball_control  acceleration  sprint_speed
# id_players
# 5717             83.0          79.0          86.0          88.0

# %%
print("\nRandom Defensive Midfielder:")
print(find_random_player_by_style('Midfielder', 'Defensive'))
# Out:
# Random Defensive Midfielder:
#            player_name  overall_rating  short_passing  ball_control  vision  \
# id_players
# 10530       Uros Matic            68.0           70.0          68.0    65.0
#
#             stamina  interceptions
# id_players
# 10530          87.0           59.0

# %%
print("\nRandom Goalkeeper:")
print(find_random_player_by_style('Goalkeeper'))
# Out:
# Random Goalkeeper:
#                player_name  overall_rating  gk_diving  gk_handling  \
# id_players
# 2610        Diego Benaglio            81.0       83.0         78.0
#
#             gk_kicking  gk_positioning  gk_reflexes
# id_players
# 2610              64.0            80.0         81.0

# %% [markdown]
# # Question 2
# - Question: What combination of physical and technical attributes defines the top-performing players?
# - Rationale: This would help a client (like a sports academy) identify attributes to target when training or recruiting players, creating a blueprint for high-potential profiles.

# %%
# Quick and Strong Attributes
speed = ['sprint_speed', 'acceleration', 'agility']
strength = ['jumping', 'stamina', 'strength', 'shot_power']

# Playmaking and Technical Attributes
playmaking = ['short_passing', 'crossing', 'long_passing', 'vision']
technical = ['ball_control', 'dribbling']

# Tactical and Goalscorer Attributes
tactician = ['aggression', 'positioning', 'interceptions']
goalscorer = ['finishing', 'long_shots', 'shot_power']

# %%
# Creating Player Traits (quick, strong, technical, playmaker, tactician)
df['is_quick'] = df[speed].gt(80).any(axis=1).astype(int)
df['is_strong'] = df[strength].gt(80).any(axis=1).astype(int)
df['is_technical'] = df[technical].gt(80).any(axis=1).astype(int)
df['is_playmaker'] = df[playmaking].gt(80).any(axis=1).astype(int)
df['is_tactician'] = df[tactician].gt(80).any(axis=1).astype(int)
df['is_goalscorer'] = df[goalscorer].gt(80).any(axis=1).astype(int)
df['world_class'] = df['overall_rating'] > 80

# %%
# Frequency of Player Traits
plt.title("Player Trait: Frequency")
df[['is_quick', 'is_strong', 'is_technical',
    'is_playmaker', 'is_tactician', 'is_goalscorer']].sum().sort_values().plot(kind = 'bar');

# %%
# Finding the Total Proportion of World Class players
df['world_class'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'gold'],
                                      labels=['Non-World Class', 'World Class'])

plt.title("Proportion of World Class Players")
plt.ylabel("")  
plt.show()

# %%
# Percentages of World Class Players by Trait
trait_columns = ['is_quick', 'is_strong', 'is_technical', 'is_playmaker', 'is_tactician', 'is_goalscorer']
trait_data = df[trait_columns]

stacked_data = pd.melt(trait_data.assign(world_class=df['world_class']),
                       id_vars=['world_class'], 
                       value_vars=trait_columns,
                       var_name='Trait', 
                       value_name='Has Trait')
stacked_data = stacked_data[stacked_data['Has Trait'] == 1]
percentages = pd.crosstab(stacked_data['Trait'], stacked_data['world_class'], normalize='index')

percentages.plot(kind='bar', stacked=True, figsize=(12, 7), colormap='viridis')
plt.title("Percentage of World Class Players by Trait")
plt.ylabel("Percentage")
plt.xlabel("Traits")
plt.legend(["Not World Class", "World Class"], title="Player Type")
plt.show()

# %% [markdown]
# * Proportionally, Goalscorers, Playmakers, and Technical players have a better percentage of World Class players.

# %%
# Distribution of Quick Players Overall
quick_players = df[df['is_quick'] == 1]

plt.figure(figsize=(10, 6))
sns.histplot(
    quick_players['overall_rating'], 
    edgecolor='black')

plt.title("Overall Rating Distribution: Quick Players", fontsize=16)
plt.xlabel("Overall Rating", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

mean_rating = quick_players['overall_rating'].mean()
plt.axvline(mean_rating, color='red', linestyle='--', label=f"Mean: {round(mean_rating, 1)}")
plt.legend(fontsize=12)
plt.show()

# %%
# Distribution of Strong Players Overall
strong_players = df[df['is_strong'] == 1]

plt.figure(figsize=(10, 6))
sns.histplot(
    quick_players['overall_rating'], 
    edgecolor='black')

plt.title("Overall Rating Distribution: Strong Players", fontsize=16)
plt.xlabel("Overall Rating", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

mean_rating = strong_players['overall_rating'].mean()
plt.axvline(mean_rating, color='red', linestyle='--', label=f"Mean: {round(mean_rating, 1)}")
plt.legend(fontsize=12)
plt.show()

# %%
# Distribution of Technical Players Overall
technical_players = df[df['is_technical'] == 1]

plt.figure(figsize=(10, 6))
sns.histplot(
    quick_players['overall_rating'], 
    edgecolor='black')

plt.title("Overall Rating Distribution: Technical Players", fontsize=16)
plt.xlabel("Overall Rating", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

mean_rating = technical_players['overall_rating'].mean()
plt.axvline(mean_rating, color='red', linestyle='--', label=f"Mean: {round(mean_rating, 1)}")
plt.legend(fontsize=12)
plt.show()

# %%
# Distribution of Playmaking Players Overall
playmaking_players = df[df['is_playmaker'] == 1]

plt.figure(figsize=(10, 6))
sns.histplot(
    quick_players['overall_rating'], 
    edgecolor='black')

plt.title("Overall Rating Distribution: Playmakers", fontsize=16)
plt.xlabel("Overall Rating", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

mean_rating = playmaking_players['overall_rating'].mean()
plt.axvline(mean_rating, color='red', linestyle='--', label=f"Mean: {round(mean_rating, 1)}")
plt.legend(fontsize=12)
plt.show()

# %%
# Distribution of Tactical Players Overall
tactical_players = df[df['is_tactician'] == 1]

plt.figure(figsize=(10, 6))
sns.histplot(
    quick_players['overall_rating'], 
    edgecolor='black')

plt.title("Overall Rating Distribution: Tacticians", fontsize=16)
plt.xlabel("Overall Rating", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

mean_rating = tactical_players['overall_rating'].mean()
plt.axvline(mean_rating, color='red', linestyle='--', label=f"Mean: {round(mean_rating, 1)}")
plt.legend(fontsize=12)
plt.show()

# %%
# Distribution of Goalscoring Players Overall
goalscoring_players = df[df['is_goalscorer'] == 1]

plt.figure(figsize=(10, 6))
sns.histplot(
    quick_players['overall_rating'], 
    edgecolor='black')

plt.title("Overall Rating Distribution: Goalscorers", fontsize=16)
plt.xlabel("Overall Rating", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

mean_rating = goalscoring_players['overall_rating'].mean()
plt.axvline(mean_rating, color='red', linestyle='--', label=f"Mean: {round(mean_rating, 1)}")
plt.legend(fontsize=12)
plt.show()

# %% [markdown]
# * Playmakers and Technical players have higher average overall_ratings of around 80.
# * This could point to the importance of these types of players in a team.
# * Playmakers and Technical players make a difference on the stats sheets with Goals and Assists and could be more highly rated on average as a result of this.

# %%
# Let's predict world class players
# We will not use some variables such as 'overall_rating' because that is what we used to define world_class players
# This model could be used to predict whether or not a player is world class based on his attributes

in_vars = ['height', 'weight', 'preferred_foot', 'attacking_work_rate',
           'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy', 
           'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 
           'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 
           'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength', 
           'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
           'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving',
           'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes',
           'is_quick', 'is_strong', 'is_playmaker', 'is_technical', 'is_tactician', 'is_goalscorer']

X = df[in_vars]
y = df['world_class'].map({True: 1, False: 0})

# Scaling variables
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns, index = X.index)
X_scaled_df = sm.add_constant(X_scaled_df)

# Fitting model
logit_model = sm.Logit(y, X_scaled_df)
result = logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.102136
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:            world_class   No. Observations:                 9192
# Model:                          Logit   Df Residuals:                     9147
# Method:                           MLE   Df Model:                           44
# Date:                Tue, 26 Nov 2024   Pseudo R-squ.:                  0.6363
# Time:                        02:12:01   Log-Likelihood:                -938.83
# converged:                       True   LL-Null:                       -2581.1
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -5.8396      0.181    -32.251      0.000      -6.195      -5.485
# height                  0.2339      0.113      2.071      0.038       0.013       0.455
# weight                  0.2920      0.106      2.746      0.006       0.084       0.500
# preferred_foot          0.0014      0.065      0.022      0.983      -0.127       0.130
# attacking_work_rate    -0.0251      0.069     -0.366      0.715      -0.160       0.109
# defensive_work_rate    -0.0097      0.064     -0.151      0.880      -0.135       0.116
# crossing               -0.3459      0.141     -2.446      0.014      -0.623      -0.069
# finishing              -0.4118      0.160     -2.575      0.010      -0.725      -0.098
# heading_accuracy        0.7541      0.143      5.281      0.000       0.474       1.034
# short_passing          -0.3183      0.187     -1.701      0.089      -0.685       0.048
# volleys                -0.0647      0.138     -0.468      0.640      -0.336       0.206
# dribbling              -0.1253      0.199     -0.630      0.529      -0.516       0.265
# curve                  -0.2786      0.139     -2.002      0.045      -0.551      -0.006
# free_kick_accuracy      0.0853      0.099      0.862      0.389      -0.109       0.279
# long_passing           -0.0590      0.106     -0.558      0.577      -0.266       0.148
# ball_control            1.4209      0.270      5.263      0.000       0.892       1.950
# acceleration            0.3315      0.181      1.830      0.067      -0.024       0.686
# sprint_speed            0.4245      0.172      2.466      0.014       0.087       0.762
# agility                -0.0503      0.130     -0.389      0.698      -0.304       0.204
# reactions               1.5557      0.119     13.043      0.000       1.322       1.789
# balance                 0.2822      0.100      2.810      0.005       0.085       0.479
# shot_power             -0.1030      0.147     -0.699      0.485      -0.392       0.186
# jumping                -0.0077      0.085     -0.091      0.927      -0.174       0.158
# stamina                -0.3009      0.124     -2.420      0.016      -0.545      -0.057
# strength               -0.0027      0.116     -0.024      0.981      -0.231       0.225
# long_shots              0.1906      0.153      1.247      0.212      -0.109       0.490
# aggression             -0.2878      0.106     -2.718      0.007      -0.495      -0.080
# interceptions           0.2573      0.116      2.209      0.027       0.029       0.486
# positioning            -0.7452      0.131     -5.670      0.000      -1.003      -0.488
# vision                  0.4491      0.122      3.684      0.000       0.210       0.688
# penalties               0.5112      0.109      4.680      0.000       0.297       0.725
# marking                 0.3220      0.220      1.466      0.143      -0.108       0.753
# standing_tackle         0.1821      0.252      0.723      0.470      -0.312       0.676
# sliding_tackle         -0.0936      0.206     -0.455      0.649      -0.497       0.310
# gk_diving               1.3074      0.257      5.081      0.000       0.803       1.812
# gk_handling             0.4090      0.311      1.314      0.189      -0.201       1.019
# gk_kicking             -0.0705      0.099     -0.715      0.475      -0.264       0.123
# gk_positioning          0.4683      0.310      1.509      0.131      -0.140       1.076
# gk_reflexes            -0.1267      0.333     -0.380      0.704      -0.780       0.527
# is_quick                0.3709      0.084      4.412      0.000       0.206       0.536
# is_strong               0.3815      0.085      4.495      0.000       0.215       0.548
# is_playmaker            0.3390      0.055      6.137      0.000       0.231       0.447
# is_technical            0.6010      0.061      9.813      0.000       0.481       0.721
# is_tactician            0.6270      0.060     10.452      0.000       0.509       0.745
# is_goalscorer           0.2211      0.059      3.752      0.000       0.106       0.337
# =======================================================================================
#
# Possibly complete quasi-separation: A fraction 0.15 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.

# %%
threshold = 0.5
predicted_probs = result.predict(X_scaled_df)
predicted_classes = (predicted_probs >= threshold).astype(int)
accuracy = (predicted_classes == y).mean()
print(f"Training Accuracy: {accuracy:.4f}")
# Out:
# Training Accuracy: 0.9592

# %%
# The coefficients are log-odds
# Let's plot the most relevant features

coefficients = result.params[1:]
features = X_scaled_df.columns[1:]
coeff_df = pd.DataFrame({'Feature': features, 'Coefficient': coefficients})
coeff_df['Abs_Coefficient'] = coeff_df['Coefficient'].abs()
coeff_df = coeff_df.sort_values('Abs_Coefficient', ascending = False)

# Plot 10 biggest absolute coefficients
plt.figure(figsize=(10, 6))
plt.barh(coeff_df['Feature'][:10], coeff_df['Coefficient'][:10], color='skyblue')
plt.xlabel('Coefficient Value')
plt.title('Top 10 Features by Importance (Absolute Coefficient Value)')
plt.gca().invert_yaxis()  
plt.show()

# %%
# Testing on sample well known players
def world_classifier(name, threshold = 0.5):
    X_ = df[df['player_name'] == name][in_vars]
    X_scaled_ = scaler.transform(X_)
    X_scaled_df_ = pd.DataFrame(X_scaled_, columns=X_.columns, index = X_.index)
    X_scaled_df_ = sm.add_constant(X_scaled_df_, has_constant = 'add')
    prediction_proba = result.predict(X_scaled_df_)
    print(f"{name}'s Prediction Probability\n")
    print(prediction_proba)

# %%
world_classifier(name='Lionel Messi')
# Out:
# Lionel Messi's Prediction Probability
#
# id_players
# 6176    0.98682
# dtype: float64

# %%
world_classifier(name='Cristiano Ronaldo')
# Out:
# Cristiano Ronaldo's Prediction Probability
#
# id_players
# 1995    0.994303
# dtype: float64

# %% [markdown]
# * Reactions and Ball Control are important attributes for World Class players according to the log-odds coefficients.
# * Interestingly, Positioning has a negative log-odds based on our model coefficients.

# %% [markdown]
# # Question 3
# - Question: How do specific attributes correlate with overall player rating?
# - Rationale: For a client in sports management or a team looking to recruit, understanding which attributes drive player success is crucial. This analysis could highlight the most critical skills for high performance.

# %%
# Correlation with Overall Rating
correlation = df.corr(numeric_only=True)['overall_rating'].sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 10))
sns.heatmap(correlation.to_frame(), annot=True, cmap='coolwarm', cbar=True, fmt=".2f")
plt.title('Top 10 Correlations with Overall Rating')
plt.show()

# %% [markdown]
# * potential is highly correlated with overall_rating.
# * the heatmap suggest that elite players could tend to have high level reactions which we saw in the previous analysis
# * playmaking attributes *(vision, long_passing, short_passing)* are the next most related attributes to overall_rating

# %%
# Average Potential per Player Trait
trait_overalls = {}
for trait in trait_columns:
    trait_overalls[trait] = df[df[trait] == 1]['overall_rating'].mean()
trait_overalls = pd.DataFrame.from_dict(trait_overalls, orient='index', columns=['Average Overall'])
trait_overalls = trait_overalls.sort_values(by='Average Overall', ascending=False)


plt.figure(figsize=(10, 6))
bars = plt.barh(trait_overalls.index, trait_overalls['Average Overall'], color='skyblue')
for bar in bars:
    plt.text(bar.get_width() + 0.1, bar.get_y() + bar.get_height()/2, 
             f"{bar.get_width():.2f}", va='center', fontsize=10)
plt.title("Average Overall per Trait", fontsize=14)
plt.xlabel("Average Overall Rating", fontsize=12)
plt.ylabel("Player Traits", fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# * Technical players and playmakers tend to have higher overall ratings based on the average overall per trait.

# %%
# Lasso Regression of Potential
in_vars = ['height', 'weight', 'preferred_foot', 'attacking_work_rate',
           'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy', 
           'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 
           'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 
           'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength', 
           'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
           'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving',
           'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes',
           'is_quick', 'is_strong', 'is_playmaker', 'is_technical', 'is_tactician', 'is_goalscorer']

X = df[in_vars]
y = df['overall_rating']


lasso_pipeline = Pipeline([
    ('scaler', StandardScaler()),  
    ('lasso', LassoCV(cv=5, random_state=0)) 
])

lasso_pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('lasso', LassoCV(cv=5, random_state=0))])

# %%
cv_scores = cross_val_score(lasso_pipeline, X, y, cv=5, scoring='r2') 
print(f"Cross-validated R^2 scores: {cv_scores}")
print(f"Mean R^2 score: {np.mean(cv_scores):.3f}")
# Out:
# Cross-validated R^2 scores: [0.82654245 0.8251317  0.84099148 0.8190909  0.82706409]
# Mean R^2 score: 0.828

# %%
lasso_model = lasso_pipeline.named_steps['lasso']
coef = lasso_model.coef_
coefficients_df = pd.DataFrame({'Feature': X.columns, 'Coefficient': coef})

coefficients_df.set_index('Feature').sort_values('Coefficient').plot(kind='barh', figsize=(10, 8),
                                                                     legend=False, title = 'Lasso Regression Feature Importance: All Features')
plt.xlabel('Coefficient Value')
plt.ylabel('Features')
plt.show()

# %%
coefficients_df.set_index('Feature').sort_values('Coefficient').tail(10).plot(kind='barh', figsize=(10, 8),
                                                                            legend=False, title = 'Lasso Regression Feature Importance: Top 10 Positive')
plt.xlabel('Coefficient Value')
plt.ylabel('Features')
plt.show()

# %% [markdown]
# * For outfielders, ball control is the attribute with the highest positive impact on potential
# * For goalkeepers, this is GK Diving
# * There are some negative coefficients, meaning that they have a negative impact on potential using our model

# %% [markdown]
# # Question 4
# * Question: What factors influence a player's potential rating, and how accurately can it predict future performance?
# * Rationale: This could assist in scouting and investment decisions for clients, focusing on young players who may grow into valuable assets.

# %%
# Let's filter out the older players so that we can fit a model for young talents
young = df[df['age'] < 30]
young.shape[0]
# Out:
# 649

# %%
in_vars = ['height', 'weight', 'preferred_foot', 'attacking_work_rate',
           'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy', 
           'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 
           'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 
           'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength', 
           'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
           'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving',
           'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes',
           'is_quick', 'is_strong', 'is_playmaker', 'is_technical', 'is_tactician', 'is_goalscorer']

X = young[in_vars]
y = young['potential']
X = sm.add_constant(X)
model = sm.OLS(np.array(y), np.array(X)).fit()

# %%
# Linear Regression to predict y = potential
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.679
# Method:                 Least Squares   F-statistic:                     32.10
# Date:                Tue, 26 Nov 2024   Prob (F-statistic):          2.26e-129
# Time:                        02:44:57   Log-Likelihood:                -1735.0
# No. Observations:                 649   AIC:                             3560.
# Df Residuals:                     604   BIC:                             3761.
# Df Model:                          44
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const
+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# * The biggest coefficients are for x39, x41, x42, and x43

# %%
for x in [39, 41, 42, 43]:
    print(X.columns[x])
# Out:
# is_quick
# is_playmaker
# is_technical
# is_tactician

# %% [markdown]
# * These for

# %%
# NOTE! 
# Improve model later for better R2
# Add and remove variables (LASSO REGRESSION!)
# Some variables are not as impactful and we may be overfitting to the young players
# Predict for young players who improved since the dataset

# %%
df.corr(numeric_only = True)['potential'].sort_values(ascending = False).head(10)
# Out:
# potential         1.000000
# overall_rating    0.842297
# reactions         0.671149
# vision            0.460524
# is_technical      0.429097
# ball_control      0.407802
# short_passing     0.390629
# penalties         0.382339
# is_playmaker      0.380305
# positioning       0.377082
# Name: potential, dtype: float64

# %% [markdown]
# * The 10 variables with the most positive correlation towards potential

# %%
# Scatterplot
plt.scatter(df['potential'], df['reactions'])

# %% [markdown]
# * As your reaction skills increase, there is a notable positive relationship with increased potential.
# * This idea was also indicated by our findings with overall_rating in Question 1.

# %% [markdown]
# # Question 5
# * Question: Which skills show the most improvement with player experience or age?
# * Rationale: This could guide a training organization on which skills to focus on at different player development stages, aligning with age or experience.

# %%
df['age'].hist();
df['age'].describe()
# Out:
# count    9192.000000
# mean       36.713338
# std         5.136603
# min        25.000000
# 25%        33.000000
# 50%        36.000000
# 75%        40.000000
# max        55.000000
# Name: age, dtype: float64

# %%
# Let's create age ranges for the players
    # 26 and below = young
    # 27 to 30 = prime
    # 31 to 35 = veteran
    # 36 + = senior

df['age_category'] = pd.cut(df['age'],
                            bins=[0, 26, 30, 35, np.inf],  
                            labels=['young', 'prime', 'veteran', 'senior'])
df['age_category'].value_counts().plot(kind = 'bar');

# %% [markdown]
# * Because this dataset comes from an earlier version of the FIFA games, most of the players are currently in the senior category.

# %%
df.corr(numeric_only=True)['age'].sort_values(ascending = False).head(5)
# Out:
# age               1.000000
# gk_kicking        0.456949
# overall_rating    0.402570
# reactions         0.299402
# strength          0.269103
# Name: age, dtype: float64

# %% [markdown]
# * Here we check which variables have the strongest positive relationship with age.
# * According to the pearson correlations, goalkeeper kicking is the attribute that improves the most with age.

# %%
# Attributes Columns
skill_columns = [
    'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys',
    'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 'ball_control',
    'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance',
    'shot_power', 'jumping', 'stamina', 'strength', 'long_shots',
    'aggression', 'interceptions', 'positioning', 'vision', 'penalties',
    'marking', 'standing_tackle', 'sliding_tackle'
]

# Group by age_category and calculate mean for each skill
age_grouped_skills = df.groupby('age_category', observed = False)[skill_columns].mean()

# Plot trends for each skill
plt.figure(figsize=(14, 8))
for skill in skill_columns:
    plt.plot(age_grouped_skills.index, age_grouped_skills[skill], label=skill)

plt.title('Skill Trends Across Age Categories')
plt.xlabel('Age Category')
plt.ylabel('Average Skill Value')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize='small', ncol=2)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# * We can observe that most skills (on average) increase from young to prime and then flatten out or decrease after this age category

# %%
# What are the skills that improve most with age?
skill_changes = age_grouped_skills.diff().sum().sort_values(ascending=False)
print("Skills that improve the most with age:")
print(skill_changes[skill_changes > 0].head(10))

print("\nSkills that decline the most with age:")
print(skill_changes[skill_changes < 0].tail(10))
# Out:
# Skills that improve the most with age:
# long_shots            17.553787
# interceptions         16.271787
# crossing              16.136135
# free_kick_accuracy    15.590026
# reactions             15.486563
# shot_power            15.120587
# aggression            15.116024
# long_passing          15.059026
# positioning           14.965515
# vision                14.089008
# dtype: float64
#
# Skills that decline the most with age:
# acceleration   -0.190896
# dtype: float64

# %% [markdown]
# * Various skills improve with age especially long_shots and interceptions
# * The only skill that declined on average between the age groups was acceleration

# %% [markdown]
# # Question 6
# * Question: Do physical attributes (height, weight) correlate with certain skill attributes? For example, are taller players better at defending or goalkeeping?
# * Rationale: This would help clients in fitness and training management understand how physicality impacts skill development.

# %%
df['tall'] = df['height'] > 190

# %%
plt.title("Pie Chart: Tall Players (over 190cm)")
df['tall'].value_counts().plot(kind = 'pie')
plt.ylabel("")
plt.show()

# %%
# Seeing the proportion of tall players per position
pd.crosstab(df['position'], df['tall']).plot(kind = 'bar', stacked = True)
plt.show()

# %% [markdown]
# * Center Backs, Center Forwards, and Goalkeepers have the biggest proportions and frequencies of taller players.
# * Teams may prefer that players who play at the center of the field are taller in stature as compared to wing players.

# %%
# Heavy players over 200 pounds
df['heavy'] = df['weight'] > 180

# %%
plt.title("Pie Chart: Heavy Players (over 180 pounds)")
df['heavy'].value_counts().plot(kind = 'pie')
plt.ylabel("")
plt.show()

# %%
# Seeing the proportion of heavy players per position
pd.crosstab(df['position'], df['heavy']).plot(kind = 'bar', stacked = True)
plt.show()

# %% [markdown]
# * The results for heavy players are identical to the previous of tall players.
# * Central playing footballers tend to be heavier, especially Goalkeepers.
# * There are certain playstyles for Center Backs and Center Forwards such as the 'Target Man' which capitalize on bigger physique players in the center of the field.

# %% [markdown]
# # Question 7
# * Question: Do certain countries do a better job of breeding certain playstyles? Italy is praised for their 3 Center Backs defensive style and Spain for their playmakers.
# * Rationale: Countries may intentionally raise young players with these playstyles to fit into their national teams in the future.

# %%
# Let's focus on Spain, Italy, England, France, and Brazil
italy = df[df['country'] == 'Italy']
england = df[df['country'] == 'England']
france = df[df['country'] == 'France']
brazil = df[df['country'] == 'Brazil']
countries = {'ITALY': italy,
             'ENGLAND': england,
             'FRANCE': france,
             'BRAZIL': brazil}

# %%
for country in countries.items():
    print(country[0])
    print(country[1]['Player_Type'].value_counts())
    print()
# Out:
# ITALY
# Player_Type
# Defender (Defensive)      163
# Midfielder (Defensive)    161
# Forward (Attacking)       143
# Goalkeeper                 80
# Midfielder (Attacking)     36
# Name: count, dtype: int64
#
# ENGLAND
# Player_Type
# Forward (Attacking)       169
# Defender (Defensive)      164
# Midfielder (Defensive)    115
# Goalkeeper                 45
# Midfielder (Attacking)     28
# Name: count, dtype: int64
#
# FRANCE
# Player_Type
# Defender (Defensive)      215
# Forward (Attacking)       183
# Midfielder (Defensive)    150
# Goalkeeper                 73
# Midfielder (Attacking)     61
# Name: count, dtype: int64
#
# BRAZIL
# Player_Type
# Forward (Attacking)       168
# Defender (Defensive)      131
# Midfielder (Defensive)    110
# Goalkeeper                 36
# Midfielder (Attacking)     30
# Name: count, dtype: int64

# %% [markdown]
# **According to the counts of each player type for each country:**
# 1. Italy, as expected, breeds a lot of Defenders type players.
# 2. England has a lot of Forwards and Defenders.
# 3. France has the biggest amount of Defenders.
# 4. Brazil raises a lot of Attackers.

# %%
for country in countries.items():
    print(country[0])
    best_position = country[1].groupby('position').agg({'overall_rating': 'mean'}).sort_values('overall_rating', ascending = False).head(1)
    print(round(best_position))
    print()
# Out:
# ITALY
#           overall_rating
# position
# SS                  77.0
#
# ENGLAND
#           overall_rating
# position
# AM                  73.0
#
# FRANCE
#           overall_rating
# position
# SS                  74.0
#
# BRAZIL
#           overall_rating
# position
# LM                  87.0

# %% [markdown]
# **Here we print the top position of each country based on their highest average rated position**
# 1. Italy - Second Striker
# 2. England - Attacking Midfielder
# 3. France - Second Striker
# 4. Brazil - Left Midfielder

# %%
for country in countries.items():
    print(country[0])
    print(country[1]['position'].value_counts().head(1))
    print()
# Out:
# ITALY
# position
# CB    120
# Name: count, dtype: int64
#
# ENGLAND
# position
# CF    105
# Name: count, dtype: int64
#
# FRANCE
# position
# CB    133
# Name: count, dtype: int64
#
# BRAZIL
# position
# CB    106
# Name: count, dtype: int64

# %% [markdown]
# **The most common position in the country**
# 1. Italy - Center Back
# 2. England - Center Forward
# 3. France - Center Back
# 4. Brazil - Center Back

# %% [markdown]
# # Question 8
# * Question: What countries have the players with the most potential? Nations like France have dominated in recent years with regards to young talent, we can explore this using our dataset.
# * Rationale: Teams that are looking to recruit players for their youth squads can set up scouting networks in countries with high potential youth.

# %%
# Get the countries with at least 100 players so that our analysis is not biased 
country_counts = df['country'].value_counts()  
valid_countries = country_counts[country_counts >= 100].index 
df_filtered = df[df['country'].isin(valid_countries)]

# %%
# The countries that have at least 100 players
print("Countries with at least 100 players")
for country in df_filtered['country'].unique():
    print(f"- {country}")
# Out:
# Countries with at least 100 players
# - England
# - Ireland
# - Germany
# - Netherlands
# - Scotland
# - Spain
# - France
# - Senegal
# - Italy
# - Brazil
# - Poland
# - Serbia
# - Switzerland
# - Belgium
# - Argentina
# - Portugal

# %%
# The top countries in terms of average potential
plt.title("Top Countries in terms of average potential")
df_filtered.groupby('country')['potential'].mean().sort_values(ascending = False).plot(kind = 'bar')
plt.show()

# %% [markdown]
# Among the countries with at least 100 players, the countries with the most potential are:
# 1. Argentina
# 2. Spain
# 3. Italy
# * Note: high overall players in the game will also have a high potential, we need to investigate potential for only younger players

# %%
# Let's filter the players who are less than 30 years old
# Keep in mind, the dataset is outdated 
df_filtered_young = df_filtered[df_filtered['age'] < 30]
df_filtered_young.shape
# Out:
# (465, 56)

# %%
# The top countries in terms of average potential
plt.title("Top Countries in terms of average potential")
df_filtered_young.groupby('country')['potential'].mean().sort_values(ascending = False).plot(kind = 'bar')
plt.show()

# %% [markdown]
# * Now, Portugal beats Argentina.

# %%
# Let's see high potential players
df_filtered.loc[:, 'young_high_potential'] = (df_filtered['age'] < 30) & (df_filtered['potential'] > 70)
pd.crosstab(df_filtered['country'], df_filtered['young_high_potential']).plot(kind = 'bar', stacked = True, figsize = (20, 10))
plt.show()

# %% [markdown]
# * According to our plot, France has the biggest amount of young, high potential players.
# * Countries like Germany and Netherlands also show a bigger proportion of these types of players.
